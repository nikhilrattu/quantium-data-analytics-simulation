# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_cust = pd.read_csv('QVI_purchase_behaviour.csv')
df_cust.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df_cust.isna().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df_cust.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cust['LIFESTAGE'].value_counts()
# Out:
# LIFESTAGE
# RETIREES                  14805
# OLDER SINGLES/COUPLES     14609
# YOUNG SINGLES/COUPLES     14441
# OLDER FAMILIES             9780
# YOUNG FAMILIES             9178
# MIDAGE SINGLES/COUPLES     7275
# NEW FAMILIES               2549
# Name: count, dtype: int64

# %%
df_transc = pd.read_excel('E:\Work\Forage\Quantium\QVI_transaction_data.xlsx')
df_transc.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %%
df_transc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df_transc[df_transc.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [DATE, STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES]
# Index: []

# %%
df_transc.drop_duplicates(inplace=True)

# %%
df_transc.duplicated().sum()
# Out:
# np.int64(0)

# %%
### RESETTING INDEX

# %%
df_transc.reset_index(drop=True, inplace=True)

# %%
df=pd.merge(df_cust, df_transc, on='LYLTY_CARD_NBR',how='inner')
df
# Out:
#         LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER   DATE  \
# 0                 1000  YOUNG SINGLES/COUPLES          Premium  43390
# 1                 1002  YOUNG SINGLES/COUPLES       Mainstream  43359
# 2                 1003         YOUNG FAMILIES           Budget  43531
# 3                 1003         YOUNG FAMILIES           Budget  43532
# 4                 1004  OLDER SINGLES/COUPLES       Mainstream  43406
# ...                ...                    ...              ...    ...
# 264830         2370701         YOUNG FAMILIES       Mainstream  43442
# 264831         2370751         YOUNG FAMILIES          Premium  43374
# 264832         2370961         OLDER FAMILIES           Budget  43397
# 264833         2370961         OLDER FAMILIES           Budget  43400
# 264834         2373711  YOUNG SINGLES/COUPLES       Mainstream  43448
#
#         STORE_NBR  TXN_ID  PROD_NBR                                 PROD_NAME  \
# ...
